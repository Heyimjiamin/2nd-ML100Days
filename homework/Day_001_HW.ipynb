# %% [markdown]
# # 作業1：
# ### 一、你選的這組資料為何重要
# ### 答：在眾多的財務投資領域中，新聞往往扮演一個很重大的角色，因為它會影響股市的表現，對於世界及的公司有重大財務影響。
# ### 二、資料從何而來 (tips: 譬如提供者是誰、以什麼方式蒐集)
# ### 由 Intrinio 公司提供的市場數據
# ### Thomson Reuter 公司提供的新聞數據
# ### 三、蒐集而來的資料型態為何
# ### 市場數據：opening price, closing price, trading volume, calculated returns (數值)
# ### 新聞數據：news articles/alerts published about assets, such as article details, sentiment, and other commentary（文字）
# ### 四、這組資料想解決的問題如何評估
# ### 利用預測 signed confidence value 來評估問題。
# ### 五、競賽題目：Two Sigma: Using News to Predict Stock Movements（Use news analytics to predict stock price performance）
# ### 六、資料來源：https://www.kaggle.com/c/two-sigma-financial-news/overview

# %% [markdown]
# # 作業2：想像你經營一個自由載客車隊，你希望能透過數據分析以提升業績，請你思考並描述你如何規劃整體的分析/解決方案：
# ### 一、核心問題為何 (tips：如何定義 「提升業績 & 你的假設」)：如何提升業績：哪種類型的人才會搭自由載客車隊、開車地點、單位時間、如何讓更多人知道此我的服務。
# ### 三、資料從何而來 (tips：哪些資料可能會對你想問的問題產生影響 & 資料如何蒐集)：分析各個年齡層會搭自由載客車隊的人、各大社群網站之留言板（如：臉書、ptt、IG、line）、各單位時間會有需求的人數與其工作類型等等。
# ### 四、蒐集而來的資料型態為何：文字與數值。
# ### 五、你要回答的問題，其如何評估（tips：你的假設如何驗證）：利用迴歸 (Mean Squared Error, MSE)來預測業績的提升。

# %% [markdown]
# ## 練習時間
# #### 請寫一個函式用來計算 Mean Square Error
# $ MSE = \frac{1}{n}\sum_{i=1}^{n}{(Y_i - \hat{Y}_i)^2} $
#
# ### Hint: [如何取平方](https://googoodesign.gitbooks.io/-ezpython/unit-1.html)

# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
def mean_squared_error(y, yp):
    """
    請完成這個 Function 後往下執行
    """
    mse = (sum((y - yp))**2)  / len(y)
    return mse

MSE = mean_squared_error(y, y_hat)
#print("The Mean squared error is %.3f" % (MSE))

# %%
def mean_absolute_error(y, yp):
    mae = MAE = sum(abs(y - yp)) / len(y)
    return mae

MAE = mean_absolute_error(y, y_hat)
#print("The Mean absolute error is %.3f" % (MAE))

# %%
w = 3
b = 0.5

x_lin = np.linspace(0, 100, 101)

y = (x_lin + np.random.randn(101) * 5) * w + b

plt.plot(x_lin, y, 'b.', label = 'data points')
plt.title("Assume we have data points")
plt.legend(loc = 2)
plt.show()

# %%
y_hat = x_lin * w + b
plt.plot(x_lin, y, 'b.', label = 'data')
plt.plot(x_lin, y_hat, 'r-', label = 'prediction')
plt.title("Assume we have data points (And the prediction)")
plt.legend(loc = 2)
plt.show()

# %%
# 執行 Function, 確認有沒有正常執行
MSE = mean_squared_error(y, y_hat)
MAE = mean_absolute_error(y, y_hat)
print("The Mean squared error is %.3f" % (MSE))
print("The Mean absolute error is %.3f" % (MAE))
# Out:
# The Mean squared error is 2.583
# The Mean absolute error is 11.144
